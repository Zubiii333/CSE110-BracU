# %%
#task5
text = input("Enter a word: ")
for i in range(len(text)):
    for len in range(i + 1, len(text) + 1):
        print(text[i: len])
    break
# Out:
# Enter a numer: Bangla
# B
# Ba
# Ban
# Bang
# Bangl
# Bangla

# %%
#task6
Text = input("Enter a word :")
for i in Text:
    s = ord(i)
    print(i ,':', s)
# Out:
# Enter a word :Hello
# H : 72
# e : 101
# l : 108
# l : 108
# o : 111
